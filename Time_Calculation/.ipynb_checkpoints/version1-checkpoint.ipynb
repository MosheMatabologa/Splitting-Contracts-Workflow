# %%
import pandas as pd

file1 = r'C:\Users\Q624157\Desktop\Time_Problem.xlsx'

#read data from excel file

# %%
df = pd.read_excel(file1, sheet_name = "Problem")

# %%
df.head()
# Out:
#    Personnel number Initials Cost Center Employee group Employee Subgroup  \
# 0          558632.0       LA      130F10              D                DA
# 1          582975.0       LP      120F04              D                DA
# 2               NaN      NaN         NaN            NaN               NaN
# 3               NaN      NaN         NaN            NaN               NaN
# 4               NaN      NaN         NaN            NaN               NaN
#
#   Clock Date       Clock In Time      Clock Out Time  Clocking Totals (Day)  \
# 0 2024-01-21 2024-04-16 14:41:36 2024-04-16 22:30:09                    7.8
# 1 2024-01-27 2024-04-16 13:06:04 2024-04-16 22:11:23                    9.8
# 2        NaT                 NaT                 NaT                    NaN
# 3        NaT                 NaT                 NaT                    NaN
# 4        NaT                 NaT                 NaT                    NaN
#
#   17,5%\n14:00 - 18:00  23%\n18:00 -06:00          newcol
# ...

# %%
df['Clock Out Time'] = df['Clock Out Time'].astype('datetime64[ns]')
df['Clock In Time'] = df['Clock In Time'].astype('datetime64[ns]')

# %%
df['newcol']=df['Clock Out Time']-df['Clock In Time']

# %%
df['twotosix']=df['Clock Out Time']-df['Clock In Time']
# df['newcol']=df['Clock Out Time']-df['Clock In Time']

# %%
print(a)
# Out:
# 1

# %%
from datetime import datetime

# datetime(year, month, day)
a = datetime(2022, 12, 28)
print(a)

# datetime(year, month, day, hour, minute, second, microsecond)
b = datetime(2024, 4, 16, 18, 0, 0)
print(b)
# Out:
# 2022-12-28 00:00:00
# 2024-04-16 18:00:00

# %%
df['range1']=b
df.head()
# Out:
#    Personnel number Initials Cost Center Employee group Employee Subgroup  \
# 0          558632.0       LA      130F10              D                DA
# 1          582975.0       LP      120F04              D                DA
# 2               NaN      NaN         NaN            NaN               NaN
# 3               NaN      NaN         NaN            NaN               NaN
# 4               NaN      NaN         NaN            NaN               NaN
#
#   Clock Date       Clock In Time      Clock Out Time  Clocking Totals (Day)  \
# 0 2024-01-21 2024-04-16 14:41:36 2024-04-16 22:30:09                    7.8
# 1 2024-01-27 2024-04-16 13:06:04 2024-04-16 22:11:23                    9.8
# 2        NaT                 NaT                 NaT                    NaN
# 3        NaT                 NaT                 NaT                    NaN
# 4        NaT                 NaT                 NaT                    NaN
#
# ...

# %%
df['twotosix']=df['range1']-df['Clock In Time']

# %%
df.head()
# Out:
#    Personnel number Initials Cost Center Employee group Employee Subgroup  \
# 0          558632.0       LA      130F10              D                DA
# 1          582975.0       LP      120F04              D                DA
# 2               NaN      NaN         NaN            NaN               NaN
# 3               NaN      NaN         NaN            NaN               NaN
# 4               NaN      NaN         NaN            NaN               NaN
#
#   Clock Date       Clock In Time      Clock Out Time  Clocking Totals (Day)  \
# 0 2024-01-21 2024-04-16 14:41:36 2024-04-16 22:30:09                    7.8
# 1 2024-01-27 2024-04-16 13:06:04 2024-04-16 22:11:23                    9.8
# 2        NaT                 NaT                 NaT                    NaN
# 3        NaT                 NaT                 NaT                    NaN
# 4        NaT                 NaT                 NaT                    NaN
#
# ...

# %%
df.to_excel("output.xlsx")
